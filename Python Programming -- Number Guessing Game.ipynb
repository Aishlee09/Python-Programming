# %% [markdown]
# __Objective: Create a simple number-guessing game that does the following:__
# - The program generates a random number between 1 and 20 (inclusive)
# - The player has to guess the number with hints provided after each guess
# - The game gives feedback on whether the guess is too high, too low, or correct
# - The game ends when the player guesses the correct number
#
# __Requirements:__
# - Use the random module to generate a random number
# - Use a while loop to allow the player to keep guessing
# - Use if-elif-else statements to check the player's guess and give feedback
# - Use the input function to get the player's guess
# - The game should tell the player how many guesses they took when they guess correctly

# %%
import random

# %%
class GuessNum:
    def points(self, point, name1):
        global player1Score, player2Score, player3Score
        print("Point is:", point)
        if name1 == 1:
            player1Score += point
        elif name1 == 2:
            player2Score += point
        elif name1 == 3:
            player3Score += point
        pass
    
    def rounds(self):
        for i in range(3):
            random_num = random.randint(1, 20)
            print(f"\n*******  ROUND - {i+1}  *******")
            pt = trials = 0
            print("\n", random_num)

            for i in range(3):
                print(f"\nPLAYER - {i+1}")

                while True:
                    num = int(input("Predict the number:"))
                    if random_num == num:
                        point = 1
                        print(f"Congrats !! You Guessed correctly in the {trials+1} attempt!!")
                        break

                    else:
                        point = 0
                        if num < random_num:
                            print("Your number is Low ")
                        elif num < (random_num / 2):
                            print("Your number is Too Low ")
                        elif num > random_num:
                            print("Your number is Big ")
                        elif num > (random_num * 2):
                            print("Your number is Too Big ")
                        
                        trials += 1

                    if trials >= 5:
                        print("Sorry, Your trials are over ! Try Next Time !")
                        break

                trials = 0
                self.points(point, i+1)
        
            
    def __init__(self, name):
        self.rounds()
        self.name = name
        pass

# %%
player1Score = player2Score = player3Score = 0
p1 = GuessNum(name)
print("\nScore of Player 1: ", player1Score)
print("\nScore of Player 2: ", player2Score)
print("\nScore of Player 3: ", player3Score)
# Out:
# *******  ROUND - 1  *******
#
#  4
#
# PLAYER - 1
# Predict the number:1
# Your number is Low
# Predict the number:2
# Your number is Low
# Predict the number:3
# Your number is Low
# Predict the number:4
# Congrats !! You Guessed correctly in the 4 attempt!!
# Point is: 1
#
# PLAYER - 2
# Predict the number:4
# Congrats !! You Guessed correctly in the 1 attempt!!
# Point is: 1
#
# PLAYER - 3
# Predict the number:4
# Congrats !! You Guessed correctly in the 1 attempt!!
# Point is: 1
#
# *******  ROUND - 2  *******
#
#  16
#
# PLAYER - 1
# Predict the number:1
# Your number is Low
# Predict the number:2
# Your number is Low
# Predict the number:3
# Your number is Low
# Predict the number:12
# Your number is Low
# Predict the number:16
# Congrats !! You Guessed correctly in the 5 attempt!!
# Point is: 1
#
# PLAYER - 2
# Predict the number:16
# Congrats !! You Guessed correctly in the 1 attempt!!
# Point is: 1
#
# PLAYER - 3
# Predict the number:16
# ...

# %%
import random

class guessNum:
    def points(self, point, name1):
        global player1Score, player2Score, player3Score
        print("Point is:", point)
        if name1 == 1:
            player1Score += point
        elif name1 == 2:
            player2Score += point
        elif name1 == 3:
            player3Score += point
        pass
    
    def round(self):
        num = random.randint(1, 20)
        print(f"\n*******  ROUND - {i+1}  *******")
        pt = trials = 0
        print("\n", num)
        while True:
            guess = int(input("Enter the number: "))
            for i in range(3):
                print("******* ROUND - 1 ********")
                for i in range(3):
                    print(f"   PLAYER - {i+1}  ")
                    for i in range(5):
                        if num == guess:
                            print("Congrats, you guessed the number correctly...!")
                            pt += 1
                            break
                        else:
                            if guess < num:
                                print("Your guess is small")
                            if guess < (num / 2):
                                print("Your guess is too small")
                            if guess > num:
                                print("Your guess is big")
                            if guess > (num * 2):
                                print("Your guess is too big")
                            trials += 1

                        if trials >= 5:
                            print("Sorry, You ran out of attempts. Try next time")
                            break

                    trials = 0
                    self.points(point, i+1)
                
    def __init__(self, name):
        self.round()
        self.name = name
        pass

player1Score = player2Score = player3Score = 0
p1 = guessNum(name)
print("\nScore of Player 1: ", player1Score)
print("\nScore of Player 2: ", player2Score)
print("\nScore of Player 3: ", player3Score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5772/3986467440.py in <module>
#      53
#      54 player1Score = player2Score = player3Score = 0
# ---> 55 p1 = guessNum(name)
#      56 print("\nScore of Player 1: ", player1Score)
#      57 print("\nScore of Player 2: ", player2Score)
#
# NameError: name 'name' is not defined
