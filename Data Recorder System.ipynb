# %% [markdown]
# ## DATA RECORDER SYSTEM

# %%
# DATA RECORDER SYSTEM

print('\n😊 Welcome to databank, Add something to be with us 😊')
print('''
    --------------------------------------------------------------
    |                    SERVICES AVAILABLE                      |
    |                    >> Data Add - 1                         |
    |                    >> Data Search - 2                      |
    |                    >> Remove Data - 3                      |
    --------------------------------------------------------------
''')

while True:
    print('1️⃣ ADD DATA \n2️⃣ SEARCH DATA \n3️⃣ REMOVE DATA')
    user = int(input("Enter your choice: "))

    if user==1:
        # append mode
        file = open('data.txt', mode = 'a')
        file.write('''Python is a high level, dynamic 
        programming language which is used for this project. 
        Python 3.7 version is used as there are extensive open-source libraries 
        available for this version of python. Python is simple yet powerful, 
        dynamic and interpreted programming language, which is well known for 
        its functionality of processing natural language data. 
        ''')
        file = open('data.txt', 'r')
        print(file.read())
        print("\nYour data is added to file named as 'data.txt' 👍\n")
        file.close()

    elif user==2:
        # opening a text file
        file = open('data.txt', "r+")
        # reading the file content
        read_file = file.read()
        print(read_file)
        y = input("\nWhat you want to search?:\n")
        if y in read_file:
            print('\nString', y, 'FOUND in File.')
        else:
            print('\nString', y, 'NOT FOUND in File.')
        file.close()
    
    elif user==3:
        # opening a text file
        file = open('data.txt', "r+")
        file.truncate(0)
        print(file.read())
        print("File is empty....❕")
        file.close()
        
    else:
        print('Kindly select available service.')
            
    ch = input("\nDo you want use data services again? (yes/no): ")
    if ch=='yes' or ch=='Yes':
        continue
    else:
        print("Thanks for using our data services!\n     Have a Good Day! 😊")
        break
# Out:
# 😊 Welcome to databank, Add something to be with us 😊
#
#     --------------------------------------------------------------
#     |                    SERVICES AVAILABLE                      |
#     |                    >> Data Add - 1                         |
#     |                    >> Data Search - 2                      |
#     |                    >> Remove Data - 3                      |
#     --------------------------------------------------------------
#
# 1️⃣ ADD DATA
# 2️⃣ SEARCH DATA
# 3️⃣ REMOVE DATA
# Enter your choice: 1
# Python language is freely available at the official website.
# Since it is open-source, this means that source code is also
# available to the public. You can also download it, use it as
# well as can share it.Python is a high level, dynamic
#         programming language which is used for this project.
#         Python 3.7 version is used as there are extensive open-source libraries
# ...
